# %%
# !pip install pandas scikit-learn nltk

# %%
import pandas as pd
import nltk

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
data = {
    'Review': [
        "This movie is amazing",
        "I hated this film",
        "Best experience ever",
        "Worst movie ever",
        "Loved the acting",
        "Not good at all"
    ],
    'Sentiment': [1, 0, 1, 0, 1, 0]
}

df = pd.DataFrame(data)
df
# Out:
#                   Review  Sentiment
# 0  This movie is amazing          1
# 1      I hated this film          0
# 2   Best experience ever          1
# 3       Worst movie ever          0
# 4       Loved the acting          1
# 5        Not good at all          0

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['Review'])
y = df['Sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
predictions = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.0

# %%
test = ["This movie is fantastic"]
test_vector = vectorizer.transform(test)

print("Prediction:", model.predict(test_vector))
# Out:
# Prediction: [1]

# %% [markdown]
# **Deliverable**
# This project performs sentiment analysis using Natural Language Processing.
#
# Steps performed:
# - Text data was preprocessed and converted into numerical form using CountVectorizer.
# - A Naive Bayes model was trained on the dataset.
# - Predictions were made to classify sentiments as positive or negative.
# - Model accuracy was calculated.
#
# Conclusion:
# The model successfully classifies text sentiment, demonstrating how NLP techniques can be used for analyzing textual data.
